# %%
import pandas as pd
air25_data = pd.read_csv('cleaned_air4thai.csv')
air25_data
# Out:
#              DATETIMEDATA  PM25  WS  TEMP  RH  WD stationID
# 0     2023-12-01 00:00:00  32.6   1    30  53  49       02t
# 1     2023-12-01 01:00:00  40.5   1    30  55  51       02t
# 2     2023-12-01 02:00:00  33.8   0    29  57   5       02t
# 3     2023-12-01 03:00:00  33.7   0    29  60  30       02t
# 4     2023-12-01 04:00:00  36.0   1    28  62  19       02t
# ...                   ...   ...  ..   ...  ..  ..       ...
# 8539  2024-02-27 19:00:00  44.8   0     0   1   0       08t
# 8540  2024-02-27 20:00:00  39.9   0     0   1   0       08t
# 8541  2024-02-27 21:00:00  38.9   0     0   1   0       08t
# 8542  2024-02-27 22:00:00  39.0   0     0   1   0       08t
# 8543  2024-02-27 23:00:00  37.8   0     0   1   0       08t
#
# [8544 rows x 7 columns]

# %%
import pandas as pd
from pycaret.regression import *

# อ่านข้อมูลจากไฟล์ CSV
data = pd.read_csv('cleaned_air4thai.csv')  # แทนที่ 'your_file.csv' ด้วยชื่อไฟล์ของคุณ

# สร้างโมเดล
exp1 = setup(data, target='PM25', session_id=123)

# เปรียบเทียบและเลือกโมเดลที่ดีที่สุด
best_model = compare_models()

# ปรับแต่งโมเดลที่ดีที่สุด
tuned_model = tune_model(best_model)

# ทำนายล่วงหน้า 7 วัน
future_data = data.copy()  # อาจต้องปรับข้อมูลที่ต้องการทำนายล่วงหน้า
future_predictions = predict_model(tuned_model, data=future_data, round=0)
print("อะไรนะบอกอีกที")
# แสดงผลลัพธ์
future_predictions
# Out:
# <style type="text/css">
# #T_dd428_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_dd428">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd428_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_dd428_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd428_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd428_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_dd428_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_dd428_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd428_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_dd428_row1_col1" class="data row1 col1" >PM25</td>
#     </tr>
#     <tr>
#       <th id="T_dd428_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
import pandas as pd
from pycaret.regression import *
from datetime import datetime, timedelta

data = pd.read_csv('cleaned_air4thai.csv')

# สร้างโมเดล
exp1 = setup(data, target='PM25', session_id=123)

# เปรียบเทียบและเลือกโมเดลที่ดีที่สุด
best_model = compare_models()

# ปรับแต่งโมเดลที่ดีที่สุด
tuned_model = tune_model(best_model)

# ทำนายล่วงหน้า 7 วัน
future_data = data.copy()  # อาจต้องปรับข้อมูลที่ต้องการทำนายล่วงหน้า
future_predictions = predict_model(tuned_model, data=future_data, round=0)

# เรียงลำดับข้อมูล Categorical
future_data['DATETIMEDATA'] = pd.to_datetime(future_data['DATETIMEDATA'])
future_predictions['DATETIMEDATA'] = pd.to_datetime(future_predictions['DATETIMEDATA'])

# สร้างตารางที่มีข้อมูลเฉพาะของวันที่ 7 วันนี้
today = datetime.now().strftime('%Y-%m-%d')
future_data_7_days = future_data[future_data['DATETIMEDATA'] >= today].sort_values('DATETIMEDATA')
future_predictions_7_days = future_predictions[future_predictions['DATETIMEDATA'] >= today].sort_values('DATETIMEDATA')


# print("ข้อมูลที่นำมาทำนายล่วงหน้า 7 วัน:")
# print(future_data_7_days)

# print("\nผลลัพธ์การทำนายล่วงหน้า 7 วัน:")
# print(future_predictions_7_days)
future_data_7_days
future_predictions_7_days
# Out:
# <style type="text/css">
# #T_44d56_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_44d56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44d56_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_44d56_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44d56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44d56_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_44d56_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_44d56_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44d56_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_44d56_row1_col1" class="data row1 col1" >PM25</td>
#     </tr>
#     <tr>
#       <th id="T_44d56_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
from pycaret.regression import *
import pandas as pd

# โหลดข้อมูลที่คุณคลีนแล้ว
data = pd.read_csv('cleaned_air4thai.csv')

# ตรวจสอบว่ามีคอลัมน์ 'DATETIMEDATA' ในข้อมูลหรือไม่
if 'DATETIMEDATA' in data.columns:
    # แปลงคอลัมน์ DATETIMEDATA ให้เป็น datetime
    data['DATETIMEDATA'] = pd.to_datetime(data['DATETIMEDATA'])
    
    # สร้างคอลัมน์ใหม่
    data['hour'] = data['DATETIMEDATA'].dt.hour
    data['day_of_week'] = data['DATETIMEDATA'].dt.dayofweek
    data['day'] = data['DATETIMEDATA'].dt.day
    data['month'] = data['DATETIMEDATA'].dt.month
else:
    print("Column 'DATETIMEDATA' not found in the dataset. Please check your dataset.")

# ตั้งค่าสภาพแวดล้อม PyCaret
exp_reg = setup(data=data, target='PM25', session_id=123,
                ignore_features=['DATETIMEDATA', 'PM10', 'O3', 'CO', 'NO2', 'SO2', 'WS', 'TEMP', 'RH', 'WD'],
                numeric_features=['hour', 'day_of_week', 'day', 'month'])

# เปรียบเทียบโมเดล
best_model = compare_models()

# สร้างโมเดล
created_model = create_model(best_model)

# ปรับแต่งโมเดล
tuned_model = tune_model(created_model)

# ประเมินโมเดล
evaluate_model(tuned_model)

# บันทึกโมเดล
save_model(tuned_model, 'final_pm25_prediction_model')
# Out:
# <style type="text/css">
# #T_bf5d0_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bf5d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf5d0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bf5d0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf5d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf5d0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bf5d0_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_bf5d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf5d0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bf5d0_row1_col1" class="data row1 col1" >PM25</td>
#     </tr>
#     <tr>
#       <th id="T_bf5d0_level0_row2" class="row_heading level0 row2" >2</th>
# ...

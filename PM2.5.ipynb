# %%
import pandas as pd
air25_data = pd.read_csv('cleaned_air4thai.csv')
air25_data
# Out:
#              DATETIMEDATA  PM25  WS  TEMP  RH  WD stationID
# 0     2023-12-01 00:00:00  32.6   1    30  53  49       02t
# 1     2023-12-01 01:00:00  40.5   1    30  55  51       02t
# 2     2023-12-01 02:00:00  33.8   0    29  57   5       02t
# 3     2023-12-01 03:00:00  33.7   0    29  60  30       02t
# 4     2023-12-01 04:00:00  36.0   1    28  62  19       02t
# ...                   ...   ...  ..   ...  ..  ..       ...
# 8539  2024-02-27 19:00:00  44.8   0     0   1   0       08t
# 8540  2024-02-27 20:00:00  39.9   0     0   1   0       08t
# 8541  2024-02-27 21:00:00  38.9   0     0   1   0       08t
# 8542  2024-02-27 22:00:00  39.0   0     0   1   0       08t
# 8543  2024-02-27 23:00:00  37.8   0     0   1   0       08t
#
# [8544 rows x 7 columns]

# %%
import pandas as pd
from pycaret.regression import *

# Load cleaned data
file_path = 'cleaned_air4thai.csv'
data = pd.read_csv(file_path)

# Remove rows with missing values in the target column
data = data.dropna(subset=['PM25'])

# Setup
regression_setup = setup(data, target='PM25', session_id=123, fold_strategy='timeseries', fold=3, data_split_shuffle=False, fold_shuffle=False)

# Compare models
best_model = compare_models()

# Create DataFrame for predicting PM25 7 days ahead
predict_data = data.copy()
predict_data['DATETIMEDATA'] = pd.to_datetime(predict_data['DATETIMEDATA']) + pd.DateOffset(days=7)

# Predict PM25 7 days ahead
predictions = predict_model(best_model, data=predict_data)
predictions

# Extract and display predicted labels
predicted_labels = predictions['Label']
print(predictions.columns)
print("-----------------------------")
print(predicted_labels)
# Out:
# <style type="text/css">
# #T_49602_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_49602">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49602_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_49602_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49602_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49602_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_49602_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49602_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_49602_row1_col1" class="data row1 col1" >PM25</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_49602_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_49602_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_49602_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_49602_row3_col1" class="data row3 col1" >(5568, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_49602_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_49602_row4_col1" class="data row4 col1" >(5568, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_49602_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_49602_row5_col1" class="data row5 col1" >(3897, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_49602_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_49602_row6_col1" class="data row6 col1" >(1671, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_49602_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_49602_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_49602_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_49602_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_49602_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_49602_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_49602_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_49602_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_49602_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_49602_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_49602_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_49602_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_49602_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_49602_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_49602_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_49602_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_49602_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_49602_row15_col1" class="data row15 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_49602_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_49602_row16_col1" class="data row16 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_49602_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_49602_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_49602_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_49602_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_49602_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_49602_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_49602_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_49602_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_49602_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_49602_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_49602_row21_col1" class="data row21 col1" >010c</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e2fdb th {
#   text-align: left;
# }
# #T_e2fdb_row0_col0, #T_e2fdb_row1_col0, #T_e2fdb_row1_col1, #T_e2fdb_row1_col2, #T_e2fdb_row1_col3, #T_e2fdb_row1_col4, #T_e2fdb_row1_col5, #T_e2fdb_row1_col6, #T_e2fdb_row2_col0, #T_e2fdb_row2_col1, #T_e2fdb_row2_col2, #T_e2fdb_row2_col3, #T_e2fdb_row2_col4, #T_e2fdb_row2_col5, #T_e2fdb_row2_col6, #T_e2fdb_row3_col0, #T_e2fdb_row3_col1, #T_e2fdb_row3_col2, #T_e2fdb_row3_col3, #T_e2fdb_row3_col4, #T_e2fdb_row3_col5, #T_e2fdb_row3_col6, #T_e2fdb_row4_col0, #T_e2fdb_row4_col1, #T_e2fdb_row4_col2, #T_e2fdb_row4_col3, #T_e2fdb_row4_col4, #T_e2fdb_row4_col5, #T_e2fdb_row4_col6, #T_e2fdb_row5_col0, #T_e2fdb_row5_col1, #T_e2fdb_row5_col2, #T_e2fdb_row5_col3, #T_e2fdb_row5_col4, #T_e2fdb_row5_col5, #T_e2fdb_row5_col6, #T_e2fdb_row6_col0, #T_e2fdb_row6_col1, #T_e2fdb_row6_col2, #T_e2fdb_row6_col3, #T_e2fdb_row6_col4, #T_e2fdb_row6_col5, #T_e2fdb_row6_col6, #T_e2fdb_row7_col0, #T_e2fdb_row7_col1, #T_e2fdb_row7_col2, #T_e2fdb_row7_col3, #T_e2fdb_row7_col4, #T_e2fdb_row7_col5, #T_e2fdb_row7_col6, #T_e2fdb_row8_col0, #T_e2fdb_row8_col1, #T_e2fdb_row8_col2, #T_e2fdb_row8_col3, #T_e2fdb_row8_col4, #T_e2fdb_row8_col5, #T_e2fdb_row8_col6, #T_e2fdb_row9_col0, #T_e2fdb_row9_col1, #T_e2fdb_row9_col2, #T_e2fdb_row9_col3, #T_e2fdb_row9_col4, #T_e2fdb_row9_col5, #T_e2fdb_row9_col6, #T_e2fdb_row10_col0, #T_e2fdb_row10_col1, #T_e2fdb_row10_col2, #T_e2fdb_row10_col3, #T_e2fdb_row10_col4, #T_e2fdb_row10_col5, #T_e2fdb_row10_col6, #T_e2fdb_row11_col0, #T_e2fdb_row11_col1, #T_e2fdb_row11_col2, #T_e2fdb_row11_col3, #T_e2fdb_row11_col4, #T_e2fdb_row11_col5, #T_e2fdb_row11_col6, #T_e2fdb_row12_col0, #T_e2fdb_row12_col1, #T_e2fdb_row12_col2, #T_e2fdb_row12_col3, #T_e2fdb_row12_col4, #T_e2fdb_row12_col5, #T_e2fdb_row12_col6, #T_e2fdb_row13_col0, #T_e2fdb_row13_col1, #T_e2fdb_row13_col2, #T_e2fdb_row13_col3, #T_e2fdb_row13_col4, #T_e2fdb_row13_col5, #T_e2fdb_row13_col6, #T_e2fdb_row14_col0, #T_e2fdb_row14_col1, #T_e2fdb_row14_col2, #T_e2fdb_row14_col3, #T_e2fdb_row14_col4, #T_e2fdb_row14_col5, #T_e2fdb_row14_col6, #T_e2fdb_row15_col0, #T_e2fdb_row15_col1, #T_e2fdb_row15_col2, #T_e2fdb_row15_col3, #T_e2fdb_row15_col4, #T_e2fdb_row15_col5, #T_e2fdb_row15_col6, #T_e2fdb_row16_col0, #T_e2fdb_row16_col1, #T_e2fdb_row16_col2, #T_e2fdb_row16_col3, #T_e2fdb_row16_col4, #T_e2fdb_row16_col5, #T_e2fdb_row16_col6, #T_e2fdb_row17_col0, #T_e2fdb_row17_col1, #T_e2fdb_row17_col2, #T_e2fdb_row17_col3, #T_e2fdb_row17_col4, #T_e2fdb_row17_col5, #T_e2fdb_row17_col6 {
#   text-align: left;
# }
# #T_e2fdb_row0_col1, #T_e2fdb_row0_col2, #T_e2fdb_row0_col3, #T_e2fdb_row0_col4, #T_e2fdb_row0_col5, #T_e2fdb_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e2fdb_row0_col7, #T_e2fdb_row1_col7, #T_e2fdb_row2_col7, #T_e2fdb_row3_col7, #T_e2fdb_row4_col7, #T_e2fdb_row5_col7, #T_e2fdb_row6_col7, #T_e2fdb_row7_col7, #T_e2fdb_row8_col7, #T_e2fdb_row9_col7, #T_e2fdb_row10_col7, #T_e2fdb_row11_col7, #T_e2fdb_row12_col7, #T_e2fdb_row13_col7, #T_e2fdb_row14_col7, #T_e2fdb_row15_col7, #T_e2fdb_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e2fdb_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e2fdb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2fdb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e2fdb_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e2fdb_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e2fdb_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e2fdb_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e2fdb_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e2fdb_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e2fdb_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2fdb_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_e2fdb_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_e2fdb_row0_col1" class="data row0 col1" >0.5368</td>
#       <td id="T_e2fdb_row0_col2" class="data row0 col2" >3.2015</td>
#       <td id="T_e2fdb_row0_col3" class="data row0 col3" >1.0331</td>
#       <td id="T_e2fdb_row0_col4" class="data row0 col4" >0.8720</td>
#       <td id="T_e2fdb_row0_col5" class="data row0 col5" >0.0639</td>
#       <td id="T_e2fdb_row0_col6" class="data row0 col6" >0.0396</td>
#       <td id="T_e2fdb_row0_col7" class="data row0 col7" >0.1333</td>
#     </tr>
#     <tr>
#       <th id="T_e2fdb_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_e2fdb_row1_col0" class="data row1 col0" >Decision Tree Regressor</td>
#       <td id="T_e2fdb_row1_col1" class="data row1 col1" >0.5373</td>
#       <td id="T_e2fdb_row1_col2" class="data row1 col2" >3.2084</td>
#       <td id="T_e2fdb_row1_col3" class="data row1 col3" >1.0342</td>
#       <td id="T_e2fdb_row1_col4" class="data row1 col4" >0.8718</td>
#       <td id="T_e2fdb_row1_col5" class="data row1 col5" >0.0640</td>
#       <td id="T_e2fdb_row1_col6" class="data row1 col6" >0.0397</td>
#       <td id="T_e2fdb_row1_col7" class="data row1 col7" >0.0467</td>
#     </tr>
#     <tr>
#       <th id="T_e2fdb_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_e2fdb_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_e2fdb_row2_col1" class="data row2 col1" >0.5527</td>
#       <td id="T_e2fdb_row2_col2" class="data row2 col2" >3.2091</td>
#       <td id="T_e2fdb_row2_col3" class="data row2 col3" >1.0706</td>
#       <td id="T_e2fdb_row2_col4" class="data row2 col4" >0.8718</td>
#       <td id="T_e2fdb_row2_col5" class="data row2 col5" >0.0659</td>
#       <td id="T_e2fdb_row2_col6" class="data row2 col6" >0.0406</td>
#       <td id="T_e2fdb_row2_col7" class="data row2 col7" >0.1467</td>
#     </tr>
#     <tr>
#       <th id="T_e2fdb_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_e2fdb_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_e2fdb_row3_col1" class="data row3 col1" >0.5941</td>
#       <td id="T_e2fdb_row3_col2" class="data row3 col2" >3.2089</td>
#       <td id="T_e2fdb_row3_col3" class="data row3 col3" >1.1042</td>
#       <td id="T_e2fdb_row3_col4" class="data row3 col4" >0.8718</td>
#       <td id="T_e2fdb_row3_col5" class="data row3 col5" >0.0684</td>
#       <td id="T_e2fdb_row3_col6" class="data row3 col6" >0.0432</td>
#       <td id="T_e2fdb_row3_col7" class="data row3 col7" >0.1300</td>
#     </tr>
#     <tr>
#       <th id="T_e2fdb_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_e2fdb_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_e2fdb_row4_col1" class="data row4 col1" >0.6086</td>
#       <td id="T_e2fdb_row4_col2" class="data row4 col2" >3.2180</td>
#       <td id="T_e2fdb_row4_col3" class="data row4 col3" >1.1256</td>
#       <td id="T_e2fdb_row4_col4" class="data row4 col4" >0.8714</td>
#       <td id="T_e2fdb_row4_col5" class="data row4 col5" >0.0698</td>
#       <td id="T_e2fdb_row4_col6" class="data row4 col6" >0.0442</td>
#       <td id="T_e2fdb_row4_col7" class="data row4 col7" >0.0700</td>
#     </tr>
#     <tr>
#       <th id="T_e2fdb_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_e2fdb_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_e2fdb_row5_col1" class="data row5 col1" >0.6127</td>
#       <td id="T_e2fdb_row5_col2" class="data row5 col2" >3.2207</td>
#       <td id="T_e2fdb_row5_col3" class="data row5 col3" >1.1314</td>
#       <td id="T_e2fdb_row5_col4" class="data row5 col4" >0.8713</td>
#       <td id="T_e2fdb_row5_col5" class="data row5 col5" >0.0702</td>
#       <td id="T_e2fdb_row5_col6" class="data row5 col6" >0.0444</td>
#       <td id="T_e2fdb_row5_col7" class="data row5 col7" >0.0700</td>
#     </tr>
#     <tr>
#       <th id="T_e2fdb_level0_row6" class="row_
# <style type="text/css">
# </style>
# <table id="T_72162">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72162_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_72162_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_72162_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_72162_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_72162_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_72162_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_72162_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72162_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72162_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_72162_row0_col1" class="data row0 col1" >4.0655</td>
#       <td id="T_72162_row0_col2" class="data row0 col2" >27.6108</td>
#       <td id="T_72162_row0_col3" class="data row0 col3" >5.2546</td>
#       <td id="T_72162_row0_col4" class="data row0 col4" >-0.0003</td>
#       <td id="T_72162_row0_col5" class="data row0 col5" >0.2846</td>
#       <td id="T_72162_row0_col6" class="data row0 col6" >0.2588</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\Desktop\code\code\PM2.5\venv\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 26
#      23 predictions
#      25 # Extract and display predicted labels
# ---> 26 predicted_labels = predictions['Label']
#      27 print(predictions.columns)
#      28 print("-----------------------------")
#
# File c:\Users\HP\Desktop\code\code\PM2.5\venv\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\HP\Desktop\code\code\PM2.5\venv\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Label'

# %%
import pandas as pd
air25_data = pd.read_csv('cleaned_air4thai.csv')
air25_data
# Out:
#              DATETIMEDATA  PM25  WS  TEMP  RH  WD stationID
# 0     2023-12-01 00:00:00  32.6   1    30  53  49       02t
# 1     2023-12-01 01:00:00  40.5   1    30  55  51       02t
# 2     2023-12-01 02:00:00  33.8   0    29  57   5       02t
# 3     2023-12-01 03:00:00  33.7   0    29  60  30       02t
# 4     2023-12-01 04:00:00  36.0   1    28  62  19       02t
# ...                   ...   ...  ..   ...  ..  ..       ...
# 8539  2024-02-27 19:00:00  44.8   0     0   1   0       08t
# 8540  2024-02-27 20:00:00  39.9   0     0   1   0       08t
# 8541  2024-02-27 21:00:00  38.9   0     0   1   0       08t
# 8542  2024-02-27 22:00:00  39.0   0     0   1   0       08t
# 8543  2024-02-27 23:00:00  37.8   0     0   1   0       08t
#
# [8544 rows x 7 columns]

# %%
import pandas as pd
from pycaret.regression import *

file_path = 'cleaned_air4thai.csv'
data = pd.read_csv(file_path)

# Remove rows with missing values in the target column
data = data.dropna(subset=['PM25'])

# โปรแกรม Setup ด้วยข้อมูล
regression_setup = setup(data, target='PM25', session_id=123, fold_strategy='timeseries', fold=3, data_split_shuffle=False, fold_shuffle=False)

# เลือกและเทรนโมเดล
best_model = compare_models()

# สร้าง DataFrame สำหรับทำนาย PM25 ล่วงหน้า 7 วัน
predict_data = data.copy()
predict_data['DATETIMEDATA'] = pd.to_datetime(predict_data['DATETIMEDATA']) + pd.DateOffset(days=7)

# ทำนาย PM25 ล่วงหน้า 7 วัน
predictions = predict_model(best_model, data=predict_data)
predictions
# Out:
# <style type="text/css">
# #T_a61a6_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a61a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a61a6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a61a6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a61a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a61a6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a61a6_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a61a6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a61a6_row1_col1" class="data row1 col1" >PM25</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a61a6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a61a6_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a61a6_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a61a6_row3_col1" class="data row3 col1" >(8508, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a61a6_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a61a6_row4_col1" class="data row4 col1" >(8508, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a61a6_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a61a6_row5_col1" class="data row5 col1" >(5955, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a61a6_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a61a6_row6_col1" class="data row6 col1" >(2553, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a61a6_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a61a6_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a61a6_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_a61a6_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a61a6_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_a61a6_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a61a6_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_a61a6_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a61a6_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_a61a6_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a61a6_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_a61a6_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a61a6_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_a61a6_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a61a6_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_a61a6_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a61a6_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_a61a6_row15_col1" class="data row15 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a61a6_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_a61a6_row16_col1" class="data row16 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a61a6_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_a61a6_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a61a6_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_a61a6_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a61a6_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_a61a6_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a61a6_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_a61a6_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a61a6_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a61a6_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_a61a6_row21_col1" class="data row21 col1" >51af</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_890bc th {
#   text-align: left;
# }
# #T_890bc_row0_col0, #T_890bc_row0_col1, #T_890bc_row0_col5, #T_890bc_row0_col6, #T_890bc_row1_col0, #T_890bc_row1_col1, #T_890bc_row1_col2, #T_890bc_row1_col3, #T_890bc_row1_col4, #T_890bc_row1_col5, #T_890bc_row1_col6, #T_890bc_row2_col0, #T_890bc_row2_col1, #T_890bc_row2_col2, #T_890bc_row2_col3, #T_890bc_row2_col4, #T_890bc_row2_col6, #T_890bc_row3_col0, #T_890bc_row3_col1, #T_890bc_row3_col2, #T_890bc_row3_col3, #T_890bc_row3_col4, #T_890bc_row3_col6, #T_890bc_row4_col0, #T_890bc_row4_col2, #T_890bc_row4_col3, #T_890bc_row4_col4, #T_890bc_row5_col0, #T_890bc_row5_col1, #T_890bc_row5_col2, #T_890bc_row5_col3, #T_890bc_row5_col4, #T_890bc_row5_col5, #T_890bc_row5_col6, #T_890bc_row6_col0, #T_890bc_row6_col1, #T_890bc_row6_col2, #T_890bc_row6_col3, #T_890bc_row6_col4, #T_890bc_row6_col5, #T_890bc_row6_col6, #T_890bc_row7_col0, #T_890bc_row7_col1, #T_890bc_row7_col2, #T_890bc_row7_col3, #T_890bc_row7_col4, #T_890bc_row7_col5, #T_890bc_row7_col6, #T_890bc_row8_col0, #T_890bc_row8_col1, #T_890bc_row8_col2, #T_890bc_row8_col3, #T_890bc_row8_col4, #T_890bc_row8_col5, #T_890bc_row8_col6, #T_890bc_row9_col0, #T_890bc_row9_col1, #T_890bc_row9_col2, #T_890bc_row9_col3, #T_890bc_row9_col4, #T_890bc_row9_col5, #T_890bc_row9_col6, #T_890bc_row10_col0, #T_890bc_row10_col1, #T_890bc_row10_col2, #T_890bc_row10_col3, #T_890bc_row10_col4, #T_890bc_row10_col5, #T_890bc_row10_col6, #T_890bc_row11_col0, #T_890bc_row11_col1, #T_890bc_row11_col2, #T_890bc_row11_col3, #T_890bc_row11_col4, #T_890bc_row11_col5, #T_890bc_row11_col6, #T_890bc_row12_col0, #T_890bc_row12_col1, #T_890bc_row12_col2, #T_890bc_row12_col3, #T_890bc_row12_col4, #T_890bc_row12_col5, #T_890bc_row12_col6, #T_890bc_row13_col0, #T_890bc_row13_col1, #T_890bc_row13_col2, #T_890bc_row13_col3, #T_890bc_row13_col4, #T_890bc_row13_col5, #T_890bc_row13_col6, #T_890bc_row14_col0, #T_890bc_row14_col1, #T_890bc_row14_col2, #T_890bc_row14_col3, #T_890bc_row14_col4, #T_890bc_row14_col5, #T_890bc_row14_col6, #T_890bc_row15_col0, #T_890bc_row15_col1, #T_890bc_row15_col2, #T_890bc_row15_col3, #T_890bc_row15_col4, #T_890bc_row15_col5, #T_890bc_row15_col6, #T_890bc_row16_col0, #T_890bc_row16_col1, #T_890bc_row16_col2, #T_890bc_row16_col3, #T_890bc_row16_col4, #T_890bc_row16_col5, #T_890bc_row16_col6, #T_890bc_row17_col0, #T_890bc_row17_col1, #T_890bc_row17_col2, #T_890bc_row17_col3, #T_890bc_row17_col4, #T_890bc_row17_col5, #T_890bc_row17_col6 {
#   text-align: left;
# }
# #T_890bc_row0_col2, #T_890bc_row0_col3, #T_890bc_row0_col4, #T_890bc_row2_col5, #T_890bc_row3_col5, #T_890bc_row4_col1, #T_890bc_row4_col5, #T_890bc_row4_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_890bc_row0_col7, #T_890bc_row1_col7, #T_890bc_row2_col7, #T_890bc_row3_col7, #T_890bc_row4_col7, #T_890bc_row5_col7, #T_890bc_row6_col7, #T_890bc_row7_col7, #T_890bc_row8_col7, #T_890bc_row9_col7, #T_890bc_row10_col7, #T_890bc_row11_col7, #T_890bc_row12_col7, #T_890bc_row13_col7, #T_890bc_row15_col7, #T_890bc_row16_col7, #T_890bc_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_890bc_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_890bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_890bc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_890bc_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_890bc_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_890bc_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_890bc_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_890bc_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_890bc_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_890bc_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_890bc_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_890bc_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_890bc_row0_col1" class="data row0 col1" >6.7751</td>
#       <td id="T_890bc_row0_col2" class="data row0 col2" >94.2814</td>
#       <td id="T_890bc_row0_col3" class="data row0 col3" >9.3158</td>
#       <td id="T_890bc_row0_col4" class="data row0 col4" >0.6294</td>
#       <td id="T_890bc_row0_col5" class="data row0 col5" >0.2538</td>
#       <td id="T_890bc_row0_col6" class="data row0 col6" >0.2197</td>
#       <td id="T_890bc_row0_col7" class="data row0 col7" >0.1367</td>
#     </tr>
#     <tr>
#       <th id="T_890bc_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_890bc_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_890bc_row1_col1" class="data row1 col1" >6.8853</td>
#       <td id="T_890bc_row1_col2" class="data row1 col2" >95.4405</td>
#       <td id="T_890bc_row1_col3" class="data row1 col3" >9.3863</td>
#       <td id="T_890bc_row1_col4" class="data row1 col4" >0.6226</td>
#       <td id="T_890bc_row1_col5" class="data row1 col5" >0.2554</td>
#       <td id="T_890bc_row1_col6" class="data row1 col6" >0.2227</td>
#       <td id="T_890bc_row1_col7" class="data row1 col7" >0.1600</td>
#     </tr>
#     <tr>
#       <th id="T_890bc_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_890bc_row2_col0" class="data row2 col0" >Ridge Regression</td>
#       <td id="T_890bc_row2_col1" class="data row2 col1" >6.7720</td>
#       <td id="T_890bc_row2_col2" class="data row2 col2" >95.6786</td>
#       <td id="T_890bc_row2_col3" class="data row2 col3" >9.3779</td>
#       <td id="T_890bc_row2_col4" class="data row2 col4" >0.6204</td>
#       <td id="T_890bc_row2_col5" class="data row2 col5" >0.2505</td>
#       <td id="T_890bc_row2_col6" class="data row2 col6" >0.2172</td>
#       <td id="T_890bc_row2_col7" class="data row2 col7" >1.0433</td>
#     </tr>
#     <tr>
#       <th id="T_890bc_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_890bc_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_890bc_row3_col1" class="data row3 col1" >6.7722</td>
#       <td id="T_890bc_row3_col2" class="data row3 col2" >95.6837</td>
#       <td id="T_890bc_row3_col3" class="data row3 col3" >9.3782</td>
#       <td id="T_890bc_row3_col4" class="data row3 col4" >0.6204</td>
#       <td id="T_890bc_row3_col5" class="data row3 col5" >0.2505</td>
#       <td id="T_890bc_row3_col6" class="data row3 col6" >0.2172</td>
#       <td id="T_890bc_row3_col7" class="data row3 col7" >0.0600</td>
#     </tr>
#     <tr>
#       <th id="T_890bc_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_890bc_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_890bc_row4_col1" class="data row4 col1" >6.7715</td>
#       <td id="T_890bc_row4_col2" class="data row4 col2" >95.6705</td>
#       <td id="T_890bc_row4_col3" class="data row4 col3" >9.3774</td>
#       <td id="T_890bc_row4_col4" class="data row4 col4" >0.6204</td>
#       <td id="T_890bc_row4_col5" class="data row4 col5" >0.2505</td>
#       <td id="T_890bc_row4_col6" class="data row4 col6" >0.2171</td>
#       <td id="T_890bc_row4_col7" class="data row4 col7" >1.9867</td>
#     </tr>
#     <tr>
#       <th id="T_890bc_level0_row5" class="row_heading level0 row5" >lar</th>
#       <td id="T_890bc_row5_col0" class="data row5 col0" >Least Angle Regression</td>
#       <td id="T_890bc_row5_col1" class="data row5 col1" >6.7956</td>
#       <td id="T_890bc_row5_col2" class="data row5 col2" >96.3722</td>
#       <td id="T_890bc_row5_col3" class="data row5 col3" >9.4191</td>
#       <td id="T_890bc_row5_col4" class="data row5 col4" >0.6168</td>
#       <td id="T_890bc_row5_col5" class="data row5 col5" >0.2508</td>
#       <td id="T_890bc_row5_col6" class="data row5 col6" >0.2176</td>
#       <td id="T_890bc_row5_col7" class="data row5 col7" >1.4700</td>
#     </tr>
#     <tr>
#       <th id="T_890bc_level0_row6" cl
# <style type="text/css">
# </style>
# <table id="T_60558">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60558_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_60558_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_60558_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_60558_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_60558_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_60558_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_60558_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60558_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60558_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_60558_row0_col1" class="data row0 col1" >12.9511</td>
#       <td id="T_60558_row0_col2" class="data row0 col2" >280.7641</td>
#       <td id="T_60558_row0_col3" class="data row0 col3" >16.7560</td>
#       <td id="T_60558_row0_col4" class="data row0 col4" >0.0061</td>
#       <td id="T_60558_row0_col5" class="data row0 col5" >0.4215</td>
#       <td id="T_60558_row0_col6" class="data row0 col6" >0.4020</td>
#     </tr>
#   </tbody>
# </table>
#             DATETIMEDATA  WS  TEMP  RH  WD stationID       PM25  \
# 0    2023-12-08 00:00:00   1    30  53  49       02t  32.599998
# 1    2023-12-08 01:00:00   1    30  55  51       02t  40.500000
# 2    2023-12-08 02:00:00   0    29  57   5       02t  33.799999
# 3    2023-12-08 03:00:00   0    29  60  30       02t  33.700001
# 4    2023-12-08 04:00:00   1    28  62  19       02t  36.000000
# ...                  ...  ..   ...  ..  ..       ...        ...
# 8539 2024-03-05 19:00:00   0     0   1   0       08t  44.799999
# 8540 2024-03-05 20:00:00   0     0   1   0       08t  39.900002
# 8541 2024-03-05 21:00:00   0     0   1   0       08t  38.900002
# 8542 2024-03-05 22:00:00   0     0   1   0       08t  39.000000
# 8543 2024-03-05 23:00:00   0     0   1   0       08t  37.799999
#
#       prediction_label
# 0            39.878251
# 1            39.878251
# 2            39.847418
# 3            39.847418
# 4            39.481990
# ...                ...
# 8539         35.928618
# 8540         35.928618
# 8541         35.928618
# 8542         35.928618
# 8543         35.928618
#
# [8508 rows x 8 columns]
